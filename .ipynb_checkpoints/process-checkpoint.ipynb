# %%
from src.tests import *
import cv2
import numpy as np
from PIL import Image
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline
import time

# %%
img_path = 'examples/ExpKITTI_joint/278_org.png'
img_org = np.array(Image.open(img_path))

depth_y_path = 'examples/ExpKITTI_joint/278_depth.png'
depth_y = np.array(Image.open(depth_y_path))

# processing orignal depth images
assert(np.max(depth_y) > 255)
depth_y = depth_y.astype(np.float) / 256.

# %% [markdown]
# ## PCA

# %%
pca_img = img_org.reshape(375, -1 )
pca = PCA(n_components = 64, svd_solver='randomized').fit(pca_img)
pca_img = pca.transform(pca_img)
print(pca_img.shape )
print(np.sum(pca.explained_variance_ratio_))
img = pca.inverse_transform(pca_img)
img = img.reshape(375, 1242, 3)
# Out:
# (375, 64)
# 0.9623305609088222

# %% [markdown]
# ## Evaluation

# %%
def measure_duration(img, times = 10):
    durations = []
    for _ in range(times):
        start = time.time()
        depth = run(img)
        end = time.time()
        durations.append(end - start)
    return depth, (sum(durations) / times)

# %%
deptj
diff = measure_duration(img_org, 100) - measure_duration(img, 100)
print(round(diff, 4))
# Out:
# 0.0164

# %%
rmse = RMSE(depth_y, depth_img)
pca_rmse = RMSE(depth_y, depth_img_pca)
print('accuracy change %: ',(rmse - pca_rmse)*100/rmse )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6bc0f4905210> in <module>
# ----> 1 rmse = RMSE(depth_y, depth_img)
#       2 pca_rmse = RMSE(depth_y, depth_img_pca)
#       3 print('accuracy change %: ',(rmse - pca_rmse)*100/rmse )
#
# NameError: name 'depth_img' is not defined

# %%
def RMSE(target, prediction):
    return np.sqrt(np.mean((target - prediction)**2))

# %% [markdown]
# ## Plot

# %%
plt.figure(figsize=(36, 24))
plt.subplot(131)
plt.imshow(img_org)
plt.title('orig img')
plt.axis('off')
plt.subplot(132)
plt.imshow(depth_y, cmap='plasma', vmin=MIN_DEPTH, vmax=MAX_DEPTH)
plt.title('KITTI depth')
plt.axis('off')
plt.subplot(133)
plt.imshow(depth_img_pca, cmap='plasma', vmin=MIN_DEPTH, vmax=MAX_DEPTH)
plt.title('Predicted depth')
plt.axis('off');
